# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("DataSet.csv")

# %%
df.sample(3)
# Out:
#                                          title               location  \
# 13669                        Controls Engineer  US, PA, Philadelphia
# 7554   Inside Sales Representative-Remote Work               US, MI,
# 3820                                     Buyer        US, IL, Chicago
#
#       department salary_range  \
# 13669        NaN          NaN
# 7554         NaN          NaN
# 3820         NaN          NaN
#
#                                          company_profile  \
# 13669  <p>We Provide Full Time Permanent Positions fo...
# 7554                                                 NaN
# 3820   <p>We Provide Full Time Permanent Positions fo...
#
#                                              description  \
# 13669  <p></p>\r\n<p><b><i>(We have more than 1500+ J...
# 7554   <p>Kranq Courier is an experienced courier com...
# 3820   <p><b><i>(We have more than 1500+ Job openings...
#
#                                             requirements benefits  \
# 13669                                                NaN      NaN
# 7554   <p>Skills/ Qualifications:</p>\r\n<ul>\r\n<li>...      NaN
# 3820                                                 NaN      NaN
#
#       telecommuting has_company_logo has_questions employment_type  \
# 13669             f                f             f       Full-time
# 7554              f                f             t        Contract
# 3820              f                f             f       Full-time
#
#       required_experience required_education                    industry  \
# 13669                 NaN                NaN                         NaN
# 7554          Entry level  Bachelor's Degree  Logistics and Supply Chain
# 3820                  NaN                NaN             Market Research
#
#       function fraudulent in_balanced_dataset
# 13669      NaN          f                   f
# 7554     Sales          f                   f
# 3820       NaN          f                   f

# %%
df["fraudulent"].value_counts()
# Out:
# fraudulent
# f    17014
# t      866
# Name: count, dtype: int64

# %%
# The dataset contains 15485 legitimate job postings and 866 fraudulent ones.

# %%
df =df.drop("in_balanced_dataset",axis=1)

# %%
df = df.drop(["location","industry"],axis=1)

# %%
df["required_education"].value_counts()
# Out:
# required_education
# Bachelor's Degree                    5145
# High School or equivalent            2080
# Unspecified                          1397
# Master's Degree                       416
# Associate Degree                      274
# Certification                         170
# Some College Coursework Completed     102
# Professional                           74
# Vocational                             49
# Some High School Coursework            27
# Doctorate                              26
# Vocational - HS Diploma                 9
# Vocational - Degree                     6
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (17880, 15)

# %%
df.sample(5)
# Out:
#                                 title department salary_range  \
# 137    Head of Marketing (option CMO)        NaN          NaN
# 16746                   Web Developer        NaN          NaN
# 1922                       Data entry        NaN  20000-38000
# 8834                  General Manager        NaN          NaN
# 14173                   Makeup Artist        NaN          NaN
#
#                                          company_profile  \
# 137    <p>We are on a mission: Making cities smarter....
# 16746  <p></p>\r\n<p><b>WE ARE GLOBAL BEACH</b></p>\r...
# 1922                                                 NaN
# 8834                                                 NaN
# 14173                                                NaN
#
#                                              description  \
# 137    <p>Performance Marketing. Mobile.</p>\r\n<p>Bu...
# 16746  <p><b>This digital communications agency is se...
# 1922   <p>Data Entry Clerk</p>\r\n<p>Data Entry Clerk...
# 8834   <p>Business Development</p>\r\n<ul>\r\n<li>Dev...
# 14173  <p>Expanding Makeup Artistry Company is seekin...
#
#                                             requirements  \
# 137                                                  NaN
# 16746  <p>To be considered for this position, you mus...
# 1922   <p></p>\r\n<p>Skills/Qualifications: Organizat...
# 8834   <ul>\r\n<li>Minimum 5-8 years of retail experi...
# 14173  <p><b>Requirements</b></p>\r\n<ul>\r\n<li>Educ...
#
#                                                 benefits telecommuting  \
# 137                                                  NaN             f
# 16746                                                NaN             f
# 1922   <p> Health, Dental, Life and AD&amp;D Insuranc...             f
# 8834                                                 NaN             f
# 14173  <p>This job offers you the opportunity to gain...             f
#
#       has_company_logo has_questions employment_type required_experience  \
# 137                  t             t             NaN                 NaN
# 16746                t             t       Full-time    Mid-Senior level
# 1922                 f             f       Full-time         Entry level
# 8834                 t             f       Full-time                 NaN
# 14173                f             t        Contract                 NaN
#
#               required_education             function fraudulent
# 137                          NaN                  NaN          f
# 16746                        NaN          Engineering          f
# 1922   High School or equivalent  Accounting/Auditing          t
# 8834                         NaN           Management          f
# 14173                Unspecified                Other          f

# %%
df['final_text'] = (df['title'] + " " + 
                    df['department'] + " " +  
                    df['company_profile'] + " " + 
                    df['description'] + " " + 
                    df['requirements'] + " " + 
                    df['benefits'])

# %%
df.sample(4)
# Out:
#                              title            department salary_range  \
# 16138         Senior Ruby Engineer           Engineering          NaN
# 4273             Android Developer  Software Engineering          NaN
# 1902   Customer Service Team Lead                    NaN          NaN
# 15399     Head of Online Marketing                   NaN          NaN
#
#                                          company_profile  \
# 16138  <h3>We’re always looking for highly motivated ...
# 4273                                                 NaN
# 1902   <p>Novitex Enterprise Solutions, formerly Pitn...
# 15399  <p>hello world</p>\r\n<p>talents23_ drives the...
#
#                                              description  \
# 16138  <p>The Mobile Majority is a rapidly growing ad...
# 4273   <p>Certoid is an identity, impersonation and r...
# 1902   <p>We are currently seeking a Customer Service...
# 15399  <p>Our client offers the fitness experience of...
#
#                                             requirements  \
# 16138  <p>We're looking for an engineer with a BS/MS ...
# 4273                                                 NaN
# 1902   <p><b>Required Qualification:</b></p>\r\n<ul>\...
# 15399  <ul>\r\n<li>Relevant experience in a comparabl...
#
#                                                 benefits telecommuting  \
# 16138  <p>It’s no secret that we work hard, but we al...             f
# 4273                                                 NaN             f
# 1902                                                 NaN             f
# 15399  <ul>\r\n<li>Attractive compensation</li>\r\n<l...             f
#
#       has_company_logo has_questions employment_type required_experience  \
# 16138                t             t       Full-time    Mid-Senior level
# 4273                 t             f             NaN                 NaN
# 1902                 t             f       Full-time           Associate
# 15399                t             t       Full-time                 NaN
#
#               required_education          function fraudulent  \
# 16138          Bachelor's Degree       Engineering          f
# 4273                         NaN               NaN          f
# 1902   High School or equivalent  Customer Service          f
# 15399                        NaN         Marketing          f
#
#                                               final_text
# 16138  Senior Ruby Engineer Engineering <h3>We’re alw...
# 4273                                                 NaN
# 1902                                                 NaN
# 15399                                                NaN

# %%
df.drop(["title", "company_profile","description", "requirements", "benefits"], axis=1, inplace=True)

# %%
df.sample(3)
# Out:
#       department salary_range telecommuting has_company_logo has_questions  \
# 915          NaN          NaN             f                t             t
# 1756         NaN          NaN             f                t             t
# 16293        NaN  25000-40000             f                t             t
#
#       employment_type required_experience required_education  \
# 915         Full-time    Mid-Senior level  Bachelor's Degree
# 1756        Full-time                 NaN                NaN
# 16293       Full-time           Associate                NaN
#
#                 function fraudulent final_text
# 915    Strategy/Planning          f        NaN
# 1756      Administrative          f        NaN
# 16293              Sales          f        NaN

# %%
df["telecommuting"].value_counts()
# Out:
# telecommuting
# f    17113
# t      767
# Name: count, dtype: int64

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.sample(2)
# Out:
#       department salary_range telecommuting has_company_logo has_questions  \
# 449          NaN          NaN             f                t             f
# 16719        NaN          NaN             f                t             t
#
#       employment_type required_experience required_education     function  \
# 449               NaN                 NaN                NaN          NaN
# 16719       Full-time    Mid-Senior level                NaN  Engineering
#
#       fraudulent final_text
# 449            f        NaN
# 16719          f        NaN

# %%
df['department'] = df['department'].fillna("")

# %%
df.sample(2)
# Out:
#         department salary_range telecommuting has_company_logo has_questions  \
# 12988                       NaN             f                f             f
# 2871   Engineering          NaN             f                t             f
#
#       employment_type required_experience required_education     function  \
# 12988       Full-time                 NaN                NaN          NaN
# 2871            Other      Not Applicable                NaN  Engineering
#
#       fraudulent                                         final_text
# 12988          f                                                NaN
# 2871           f  Junior Front End Developer Engineering <p>The ...

# %%
df["salary_range"] = df["salary_range"].fillna("0")

# %%
def process_salary(salary_str):
    if pd.isna(salary_str) or salary_str == "":
        return np.nan 
    clean_str = salary_str.lower().replace('$', '').replace(',', '').replace(' ', '')

    if 'k' in clean_str:
        clean_str = clean_str.replace('k', '')
        multiplier = 1000
    else:
        multiplier = 1

    try:
        if '-' in clean_str:
            low, high = clean_str.split('-')
            avg = (float(low) + float(high)) / 2
            return avg * multiplier
        else:
            return float(clean_str) * multiplier
    except ValueError:
        return np.nan

# %%
df['salary_Fixed'] = df['salary_range'].apply(process_salary)

# %%
df.sample(3)
# Out:
#                department salary_range telecommuting has_company_logo  \
# 12817                                0             f                t
# 14299  Financial Services            0             f                t
# 16506                                0             f                t
#
#       has_questions employment_type required_experience required_education  \
# 12817             f       Full-time    Mid-Senior level        Unspecified
# 14299             f        Contract    Mid-Senior level  Bachelor's Degree
# 16506             f       Full-time           Associate  Bachelor's Degree
#
#                      function fraudulent final_text  salary_Fixed
# 12817  Information Technology          f        NaN           0.0
# 14299  Information Technology          f        NaN           0.0
# 16506             Engineering          f        NaN           0.0

# %%
df = df.drop("salary_range", axis=1)

# %%
mapping = {'t': 1, 'f': 0}
df["telecommuting"] = df["telecommuting"].map(mapping)
df["has_company_logo"] = df["has_company_logo"].map(mapping)
df["has_questions"] = df["has_questions"].map(mapping)
df["fraudulent"] = df["fraudulent"].map(mapping)

# %%
df.sample(2)
# Out:
#                department  telecommuting  has_company_logo  has_questions  \
# 11931  Technical Services              0                 1              0
# 733            Operations              1                 1              1
#
#       employment_type required_experience         required_education  \
# 11931       Full-time         Entry level                        NaN
# 733         Full-time           Associate  High School or equivalent
#
#                      function  fraudulent  \
# 11931  Information Technology           0
# 733                     Other           0
#
#                                               final_text  salary_Fixed
# 11931                                                NaN           0.0
# 733    Corporate Travel Counselor - South East Region...           0.0

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# Full-time    11620
# Contract      1524
# Part-time      797
# Temporary      241
# Other          227
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns = ["employment_type"],drop_first= True)

# %%
df.sample(3)
# Out:
#       department  telecommuting  has_company_logo  has_questions  \
# 15222                         0                 0              0
# 275                           0                 1              1
# 9820                          0                 1              1
#
#       required_experience required_education        function  fraudulent  \
# 15222                 NaN                NaN             NaN           0
# 275        Not Applicable    Master's Degree             NaN           0
# 9820                  NaN                NaN  Administrative           0
#
#       final_text  salary_Fixed  employment_type_Full-time  \
# 15222        NaN           0.0                      False
# 275          NaN           0.0                       True
# 9820         NaN       17500.0                      False
#
#        employment_type_Other  employment_type_Part-time  \
# 15222                  False                      False
# 275                    False                      False
# 9820                   False                      False
#
#        employment_type_Temporary
# 15222                      False
# 275                        False
# 9820                       False

# %%
df["required_experience"].value_counts()
# Out:
# required_experience
# Mid-Senior level    3809
# Entry level         2697
# Associate           2297
# Not Applicable      1116
# Director             389
# Internship           381
# Executive            141
# Name: count, dtype: int64

# %%
experience_map = {
    'Internship': 0,
    'Entry level': 1,
    'Not Applicable': 1,   
    'Associate': 2,
    'Mid-Senior level': 3,
    'Director': 4,
    'Executive': 5
}

# %%
df["required_experience"] = df["required_experience"].fillna("Not Applicable")

# %%
df['experience_encoded'] = df['required_experience'].map(experience_map)

# %%
df.sample(2)
# Out:
#       department  telecommuting  has_company_logo  has_questions  \
# 8942                          0                 1              0
# 9156  Operations              0                 1              0
#
#      required_experience required_education                function  \
# 8942      Not Applicable  Bachelor's Degree  Information Technology
# 9156           Associate         Vocational          Administrative
#
#       fraudulent                                         final_text  \
# 8942           0                                                NaN
# 9156           0  Personal Assistant to the CEO (m/f) Operations...
#
#       salary_Fixed  employment_type_Full-time  employment_type_Other  \
# 8942      125000.0                       True                  False
# 9156           0.0                       True                  False
#
#       employment_type_Part-time  employment_type_Temporary  experience_encoded
# 8942                      False                      False                   1
# 9156                      False                      False                   2

# %%
df = df.drop("required_experience", axis = 1)

# %%
df["required_education"].value_counts()
# Out:
# required_education
# Bachelor's Degree                    5145
# High School or equivalent            2080
# Unspecified                          1397
# Master's Degree                       416
# Associate Degree                      274
# Certification                         170
# Some College Coursework Completed     102
# Professional                           74
# Vocational                             49
# Some High School Coursework            27
# Doctorate                              26
# Vocational - HS Diploma                 9
# Vocational - Degree                     6
# Name: count, dtype: int64

# %%
df["function"].value_counts()
# Out:
# function
# Information Technology    1749
# Sales                     1468
# Engineering               1348
# Customer Service          1229
# Marketing                  830
# Administrative             630
# Design                     340
# Health Care Provider       338
# Other                      325
# Education                  325
# Management                 317
# Business Development       228
# Accounting/Auditing        212
# Human Resources            205
# Project Management         183
# Finance                    172
# Consulting                 144
# Writing/Editing            132
# Art/Creative               132
# Production                 116
# Product Management         114
# Quality Assurance          111
# Advertising                 90
# Business Analyst            84
# Data Analyst                82
# Public Relations            76
# Manufacturing               74
# General Business            68
# Research                    50
# Legal                       47
# Strategy/Planning           46
# Training                    38
# Supply Chain                36
# Financial Analyst           33
# Distribution                24
# Purchasing                  15
# Science                     14
# Name: count, dtype: int64

# %%
edu_map = {
    "Unspecified" : 0,
    "Some High School Coursework" : 0,
    'High School or equivalent': 1,
    'Vocational - HS Diploma': 1,
    
    'Certification': 2,
    'Vocational': 2,
    'Vocational - Degree': 2,
    'Associate Degree': 2,
    'Some College Coursework Completed': 2,
    'Professional': 2, 
    
    "Bachelor's Degree": 3,
    
    "Master's Degree": 4,
    
    'Doctorate': 5
}

# %%
df["required_education"] = df["required_education"].fillna("Unspecified")

# %%
df["required_education"] = df["required_education"].map(edu_map)

# %%
df.sample(2)
# Out:
#       department  telecommuting  has_company_logo  has_questions  \
# 6028                          0                 1              1
# 13890                         0                 1              1
#
#        required_education function  fraudulent final_text  salary_Fixed  \
# 6028                    0      NaN           0        NaN           0.0
# 13890                   0      NaN           0        NaN           0.0
#
#        employment_type_Full-time  employment_type_Other  \
# 6028                       False                  False
# 13890                       True                  False
#
#        employment_type_Part-time  employment_type_Temporary  \
# 6028                       False                      False
# 13890                      False                      False
#
#        experience_encoded
# 6028                    1
# 13890                   1

# %%
# now for the function column as there are more than 50 unique values we will group the less frequent ones into "Other" category
top_10_functions = df["function"].value_counts().nlargest(10).index
df['function_grouped'] = np.where(df['function'].isin(top_10_functions), df['function'], 'Other')
df_encoded = pd.get_dummies(df, columns=['function_grouped'], drop_first=True)

# %%
df.sample(2)
# Out:
#                  department  telecommuting  has_company_logo  has_questions  \
# 9654   Design & Development              1                 1              1
# 16917                                    0                 1              1
#
#        required_education function  fraudulent  \
# 9654                    0   Design           0
# 16917                   0      NaN           0
#
#                                               final_text  salary_Fixed  \
# 9654   WebDesigner (UX/UI Designer) Design & Developm...           0.0
# 16917                                                NaN           0.0
#
#        employment_type_Full-time  employment_type_Other  \
# 9654                       False                   True
# 16917                      False                  False
#
#        employment_type_Part-time  employment_type_Temporary  \
# 9654                       False                      False
# 16917                      False                      False
#
#        experience_encoded function_grouped
# 9654                    1           Design
# 16917                   1            Other

# %%
df = df.drop(["function"], axis = 1)

# %%
df["final_text"]
# Out:
# 0                                                      NaN
# 1        Customer Service - Cloud Video Production Succ...
# 2                                                      NaN
# 3        Account Executive - Washington DC Sales <p>Our...
# 4                                                      NaN
#                                ...
# 17875    Account Director - Distribution  Sales <p>Vend...
# 17876    Payroll Accountant Accounting <p>WebLinc is th...
# 17877                                                  NaN
# 17878                                                  NaN
# 17879                                                  NaN
# Name: final_text, Length: 17880, dtype: object

# %%
df.head()
# Out:
#   department  telecommuting  has_company_logo  has_questions  \
# 0  Marketing              0                 1              0
# 1    Success              0                 1              0
# 2                         0                 1              0
# 3      Sales              0                 1              0
# 4                         0                 1              1
#
#    required_education  fraudulent  \
# 0                   0           0
# 1                   0           0
# 2                   0           0
# 3                   3           0
# 4                   3           0
#
#                                           final_text  salary_Fixed  \
# 0                                                NaN           0.0
# 1  Customer Service - Cloud Video Production Succ...           0.0
# 2                                                NaN           0.0
# 3  Account Executive - Washington DC Sales <p>Our...           0.0
# 4                                                NaN           0.0
#
#    employment_type_Full-time  employment_type_Other  \
# 0                      False                   True
# 1                       True                  False
# 2                      False                  False
# 3                       True                  False
# 4                       True                  False
#
#    employment_type_Part-time  employment_type_Temporary  experience_encoded  \
# 0                      False                      False                   0
# 1                      False                      False                   1
# 2                      False                      False                   1
# 3                      False                      False                   3
# 4                      False                      False                   3
#
#        function_grouped
# 0             Marketing
# 1      Customer Service
# 2                 Other
# 3                 Sales
# 4  Health Care Provider

# %%
import re
def removehtml(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'<[^>]+>', ' ', str(text))
    
    text = text.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ')
    
    text = text.replace('/n', ' ').replace('\\n', ' ')
    
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
df['final_text'] = df['final_text'].apply(removehtml)

# %%
df.sample(5)
# Out:
#            department  telecommuting  has_company_logo  has_questions  \
# 1476                               0                 1              1
# 12002                              0                 1              1
# 17649  Administrative              0                 0              0
# 14461     Engineering              0                 1              0
# 10952                              0                 1              0
#
#        required_education  fraudulent  \
# 1476                    1           0
# 12002                   0           0
# 17649                   3           1
# 14461                   3           0
# 10952                   0           0
#
#                                               final_text  salary_Fixed  \
# 1476                                                               0.0
# 12002                                                              0.0
# 17649                                                          31510.5
# 14461  Senior Backend Engineer, Web Services Engineer...           0.0
# 10952                                                              0.0
#
#        employment_type_Full-time  employment_type_Other  \
# 1476                        True                  False
# 12002                      False                  False
# 17649                       True                  False
# 14461                       True                  False
# 10952                       True                  False
#
#        employment_type_Part-time  employment_type_Temporary  \
# 1476                       False                      False
# 12002                      False                      False
# 17649                      False                      False
# 14461                      False                      False
# 10952                      False                      False
#
#        experience_encoded function_grouped
# 1476                    1            Other
# 12002                   1            Other
# 17649                   1   Administrative
# 14461                   3      Engineering
# 10952                   0            Other

# %%
df["department"].value_counts()
# Out:
# department
#                                 11547
# Sales                             551
# Engineering                       487
# Marketing                         401
# Operations                        270
#                                 ...
# QA & Programme Delivery             1
# Private Duty                        1
# RHB OUTSOURCING                     1
# reception                           1
# IT Administrator / Developer        1
# Name: count, Length: 1338, dtype: int64

# %%
df.drop(["department"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    telecommuting  has_company_logo  has_questions  required_education  \
# 0              0                 1              0                   0
# 1              0                 1              0                   0
# 2              0                 1              0                   0
# 3              0                 1              0                   3
# 4              0                 1              1                   3
#
#    fraudulent                                         final_text  \
# 0           0
# 1           0  Customer Service - Cloud Video Production Succ...
# 2           0
# 3           0  Account Executive - Washington DC Sales Our pa...
# 4           0
#
#    salary_Fixed  employment_type_Full-time  employment_type_Other  \
# 0           0.0                      False                   True
# 1           0.0                       True                  False
# 2           0.0                      False                  False
# 3           0.0                       True                  False
# 4           0.0                       True                  False
#
#    employment_type_Part-time  employment_type_Temporary  experience_encoded  \
# 0                      False                      False                   0
# 1                      False                      False                   1
# 2                      False                      False                   1
# 3                      False                      False                   3
# 4                      False                      False                   3
#
#        function_grouped
# 0             Marketing
# 1      Customer Service
# 2                 Other
# 3                 Sales
# 4  Health Care Provider

# %%
df =pd.get_dummies(df, columns = ["function_grouped"], drop_first = True)

# %%
df.sample(3)
# Out:
#        telecommuting  has_company_logo  has_questions  required_education  \
# 4768               0                 1              0                   0
# 15925              0                 1              1                   3
# 8127               0                 1              1                   0
#
#        fraudulent final_text  salary_Fixed  employment_type_Full-time  \
# 4768            0                      0.0                      False
# 15925           0                      0.0                       True
# 8127            0                      0.0                       True
#
#        employment_type_Other  employment_type_Part-time  ...  \
# 4768                   False                      False  ...
# 15925                  False                      False  ...
# 8127                   False                      False  ...
#
#        experience_encoded  function_grouped_Customer Service  \
# 4768                    1                              False
# 15925                   2                              False
# 8127                    3                              False
#
#        function_grouped_Design  function_grouped_Education  \
# 4768                     False                       False
# 15925                    False                       False
# 8127                     False                       False
#
#        function_grouped_Engineering  function_grouped_Health Care Provider  \
# 4768                          False                                  False
# 15925                         False                                  False
# 8127                          False                                  False
#
#        function_grouped_Information Technology  function_grouped_Marketing  \
# 4768                                     False                       False
# 15925                                    False                       False
# 8127                                     False                       False
#
#        function_grouped_Other  function_grouped_Sales
# 4768                     True                   False
# 15925                   False                    True
# 8127                    False                    True
#
# [3 rows x 21 columns]

# %%
bool_cols = df.select_dtypes(include=['bool']).columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X = df.drop(['fraudulent', 'final_text'], axis=1)
y = df['fraudulent']

# %%
X_train, X_test, y_train, y_test, text_train, text_test = train_test_split(
    X, y, df['final_text'], test_size=0.2, random_state=42, stratify=y
)

# %%
tfidf = TfidfVectorizer(max_features=5000)

# %%
text_train_tfidf = tfidf.fit_transform(text_train)
text_test_tfidf = tfidf.transform(text_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from scipy.sparse import hstack
x_train_final = hstack([X_train_scaled, text_train_tfidf])
x_test_final = hstack([X_test_scaled, text_test_tfidf])

# %%
#log_reg = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)

# %%
#print("Training model...")
#log_reg.fit(x_train_final, y_train)

# %%
#y_pred = log_reg.predict(x_test_final)

# %%
#print("\n--- Model Performance ---")
#print(classification_report(y_test, y_pred))

#print("\n--- Confusion Matrix ---")
#print(confusion_matrix(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=200, 
                                  random_state=42, 
                                  class_weight='balanced_subsample')

# %%
rf_model.fit(x_train_final, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', n_estimators=200,
#                        random_state=42)

# %%
y_pred_rf = rf_model.predict(x_test_final)

# %%
print("\n--- Random Forest Performance ---")
print(classification_report(y_test, y_pred_rf))
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# --- Random Forest Performance ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94      3403
#            1       0.27      0.77      0.40       173
#
#     accuracy                           0.89      3576
#    macro avg       0.63      0.83      0.67      3576
# weighted avg       0.95      0.89      0.91      3576
#
# [[3036  367]
#  [  39  134]]

# %%
# still so many misclassifications so I am going to use XGboost so that the model can perform better

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (2.4.1)
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.17.0)
# Downloading xgboost-3.1.3-py3-none-win_amd64.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.2/72.0 MB 7.6 MB/s eta 0:00:10
#    ---------------------------------------- 0.2/72.0 MB 7.6 MB/s eta 0:00:10
#    ---------------------------------------- 0.2/72.0 MB 7.6 MB/s eta 0:00:10
#    ---------------------------------------- 0.4/72.0 MB 2.0 MB/s eta 0:00:37
#    ---------------------------------------- 0.7/72.0 MB 2.8 MB/s eta 0:00:26
#     --------------------------------------- 0.9/72.0 MB 3.5 MB/s eta 0:00:21
#     --------------------------------------- 0.9/72.0 MB 3.5 MB/s eta 0:00:21
#     --------------------------------------- 0.9/72.0 MB 3.5 MB/s eta 0:00:21
#     --------------------------------------- 1.1/72.0 MB 1.8 MB/s eta 0:00:39
#     --------------------------------------- 1.2/72.0 MB 1.7 MB/s eta 0:00:41
#     --------------------------------------- 1.2/72.0 MB 1.8 MB/s eta 0:00:40
MB 6.1 MB/s eta 0:00:02
#    --------------------------------- ------ 60.4/72.0 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 60.6/72.0 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 61.1/72.0 MB 6.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 61.5/72.0 MB 6.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 61.9/72.0 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 62.3/72.0 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 62.7/72.0 MB 6.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 63.1/72.0 MB 7.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 63.5/72.0 MB 7.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 63.9/72.0 MB 7.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 64.2/72.0 MB 7.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 64.6/72.0 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------ --- 65.0/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 65.3/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 65.8/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 66.0/72.0 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 66.4/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 66.7/72.0 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 67.0/72.0 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------- -- 67.2/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 67.5/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 67.8/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 68.1/72.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 68.4/72.0 MB 7.6 MB/s eta 0:00:01
#    -------------------------------------- - 68.6/72.0 MB 7.5 MB/s eta 0:00:01
#    -------------------------------------- - 68.9/72.0 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 69.3/72.0 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 69.6/72.0 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 69.8/72.0 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 70.1/72.0 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  70.4/72.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  70.7/72.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  71.0/72.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  71.2/72.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  71.5/72.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost
from xgboost import XGBClassifier
ratio = float(np.sum(y_train == 0)) / np.sum(y_train == 1)

# %%
xgb_model = XGBClassifier(n_estimators=100, 
                          learning_rate=0.1, 
                          max_depth=6, 
                          scale_pos_weight=ratio, 
                          use_label_encoder=False,
                          eval_metric='logloss',
                          random_state=42)

# %%
xgb_model.fit(x_train_final, y_train)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:50:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(x_test_final)

# %%
print("\n--- XGBoost Performance ---")
print(classification_report(y_test, y_pred_xgb))
print(confusion_matrix(y_test, y_pred_xgb))
# Out:
# --- XGBoost Performance ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93      3403
#            1       0.27      0.85      0.41       173
#
#     accuracy                           0.88      3576
#    macro avg       0.63      0.87      0.67      3576
# weighted avg       0.96      0.88      0.91      3576
#
# [[3008  395]
#  [  26  147]]

# %%
#just improved the recall and precision remained same

# %%
full_ratio = float(np.sum(y_train == 0)) / np.sum(y_train == 1)

# %%
tuned_weight = np.sqrt(full_ratio) 

xgb_tuned = XGBClassifier(n_estimators=200, 
                          learning_rate=0.05, 
                          max_depth=6, 
                          scale_pos_weight=tuned_weight, 
                          use_label_encoder=False,
                          eval_metric='logloss',
                          random_state=42)

# %%
xgb_tuned.fit(x_train_final, y_train)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:199: UserWarning: [23:11:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_probs = xgb_tuned.predict_proba(x_test_final)[:, 1]
threshold = 0.80
y_pred_strict = (y_probs > threshold).astype(int)

# %%
print(f"--- XGBoost with {threshold*100}% Threshold ---")
print(classification_report(y_test, y_pred_strict))
print(confusion_matrix(y_test, y_pred_strict))
# Out:
# --- XGBoost with 80.0% Threshold ---
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3403
#            1       0.89      0.32      0.47       173
#
#     accuracy                           0.97      3576
#    macro avg       0.93      0.66      0.73      3576
# weighted avg       0.96      0.97      0.96      3576
#
# [[3396    7]
#  [ 117   56]]
