# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("DataSet.csv")

# %%
df.sample(3)
# Out:
#                                                    title          location  \
# 9940                   Outside Sales Professional-Savage    US, MN, Savage
# 7128         Data Scientist (Big Data, Machine Learning)      PL, , krakow
# 16936  Friendly Customer Service Employees..Hiring Im...  US, OH, Columbus
#
#       department salary_range  \
# 9940         NaN          NaN
# 7128         NaN          NaN
# 16936        NaN          NaN
#
#                                          company_profile  \
# 9940   <p>ABC Supply Co., Inc. is the nation’s larges...
# 7128   <p>Merchenta’s behavioural advertising platfor...
# 16936  <p>LEI Home Enhancements, is an Ohio based com...
#
#                                              description  \
# 9940   <p>As an Outside Sales Representative, you wil...
# 7128   <p>We help online retailers and global brands ...
# 16936  <p><b>Seeking Experienced Customer Service Rep...
#
#                                             requirements  \
# 9940   <p>As an Outside Sales Representative, you mus...
# 7128   <p>We work with a wide range of technologies, ...
# 16936  <p><b>We're looking for candidates who are:</b...
#
#                                                 benefits telecommuting  \
# 9940   <p><b>Benefits:</b></p>\r\n<p>As an Outside Sa...             f
# 7128   <p>The role brings with it a competitive salar...             f
# 16936  <p>We offer competitive pay; benefits; trainin...             f
#
#       has_company_logo has_questions employment_type required_experience  \
# 9940                 t             f       Full-time                 NaN
# 7128                 t             f       Full-time    Mid-Senior level
# 16936                t             f             NaN                 NaN
#
#       required_education            industry          function fraudulent
# 9940                 NaN  Building Materials             Sales          f
# 7128                 NaN   Computer Software               NaN          f
# 16936                NaN                 NaN  Customer Service          f

# %%
df["fraudulent"].value_counts()
# Out:
# fraudulent
# f    17014
# t      866
# Name: count, dtype: int64

# %%
# The dataset contains 15485 legitimate job postings and 866 fraudulent ones.

# %%
df =df.drop("in_balanced_dataset",axis=1)

# %%
df = df.drop(["location","industry"],axis=1)

# %%
df["required_education"].value_counts()
# Out:
# required_education
# Bachelor's Degree                    5145
# High School or equivalent            2080
# Unspecified                          1397
# Master's Degree                       416
# Associate Degree                      274
# Certification                         170
# Some College Coursework Completed     102
# Professional                           74
# Vocational                             49
# Some High School Coursework            27
# Doctorate                              26
# Vocational - HS Diploma                 9
# Vocational - Degree                     6
# Name: count, dtype: int64
